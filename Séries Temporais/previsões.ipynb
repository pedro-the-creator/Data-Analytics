# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
from datetime import datetime
# !pip install pmdarima
from pmdarima.arima import auto_arima
# Out:
# Requirement already satisfied: pmdarima in c:\users\phlor\anaconda3\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\phlor\anaconda3\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\phlor\anaconda3\lib\site-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\phlor\anaconda3\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\phlor\anaconda3\lib\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\phlor\anaconda3\lib\site-packages (from pmdarima) (1.5.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\phlor\anaconda3\lib\site-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\phlor\anaconda3\lib\site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in c:\users\phlor\anaconda3\lib\site-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\phlor\anaconda3\lib\site-packages (from pmdarima) (75.1.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\phlor\anaconda3\lib\site-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\phlor\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\phlor\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\phlor\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\phlor\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\phlor\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in c:\users\phlor\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
dateparse = lambda dates: datetime.strptime(dates, '%Y-%m')
data = pd.read_csv('AirPassengers.csv', parse_dates=['Month'], index_col='Month',date_parser=dateparse)
# Out:
# C:\Users\phlor\AppData\Local\Temp\ipykernel_5980\1006055163.py:2: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   data = pd.read_csv('AirPassengers.csv', parse_dates=['Month'], index_col='Month',date_parser=dateparse)

# %%
data
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
plt.plot(data)

# %%
stepwise_model = auto_arima(data, start_p=1,start_q=1,start_d= 0, start_P=0, max_p=6, max_q=6, m=12, seasonal=True, trace=True, stepwise=False)
# Out:
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1031.508, Time=0.06 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=1030.752, Time=0.09 sec
#  ARIMA(0,1,0)(0,1,2)[12]             : AIC=1032.276, Time=0.20 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=1030.408, Time=0.05 sec
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=1032.128, Time=0.17 sec
#  ARIMA(0,1,0)(1,1,2)[12]             : AIC=1034.096, Time=0.32 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=1032.120, Time=0.12 sec
#  ARIMA(0,1,0)(2,1,1)[12]             : AIC=inf, Time=1.31 sec
#  ARIMA(0,1,0)(2,1,2)[12]             : AIC=inf, Time=1.27 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=1020.639, Time=0.05 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1021.003, Time=0.09 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=1019.494, Time=0.26 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=1020.425, Time=0.08 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=1020.327, Time=0.28 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=1012.991, Time=0.78 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=1019.178, Time=0.17 sec
#  ARIMA(0,1,1)(2,1,1)[12]             : AIC=inf, Time=0.99 sec
#  ARIMA(0,1,1)(2,1,2)[12]             : AIC=inf, Time=1.34 sec
#  ARIMA(0,1,2)(0,1,0)[12]             : AIC=1022.627, Time=0.09 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=1023.001, Time=0.18 sec
#  ARIMA(0,1,2)(0,1,2)[12]             : AIC=1021.453, Time=0.36 sec
#  ARIMA(0,1,2)(1,1,0)[12]             : AIC=1022.424, Time=0.15 sec
#  ARIMA(0,1,2)(1,1,1)[12]             : AIC=1022.325, Time=0.39 sec
#  ARIMA(0,1,2)(1,1,2)[12]             : AIC=1014.990, Time=0.90 sec
#  ARIMA(0,1,2)(2,1,0)[12]             : AIC=1021.148, Time=0.28 sec
#  ARIMA(0,1,2)(2,1,1)[12]             : AIC=inf, Time=1.47 sec
#  ARIMA(0,1,3)(0,1,0)[12]             : AIC=1020.204, Time=0.11 sec
#  ARIMA(0,1,3)(0,1,1)[12]             : AIC=1020.805, Time=0.25 sec
#  ARIMA(0,1,3)(0,1,2)[12]             : AIC=1020.159, Time=0.53 sec
#  ARIMA(0,1,3)(1,1,0)[12]             : AIC=1020.361, Time=0.15 sec
#  ARIMA(0,1,3)(1,1,1)[12]             : AIC=1020.618, Time=0.37 sec
#  ARIMA(0,1,3)(2,1,0)[12]             : AIC=1019.745, Time=0.26 sec
#  ARIMA(0,1,4)(0,1,0)[12]             : AIC=1020.696, Time=0.09 sec
#  ARIMA(0,1,4)(0,1,1)[12]             : AIC=1020.176, Time=0.24 sec
#  ARIMA(0,1,4)(1,1,0)[12]             : AIC=1019.607, Time=0.19 sec
#  ARIMA(0,1,5)(0,1,0)[12]             : AIC=1021.399, Time=0.16 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1020.393, Time=0.11 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=1020.914, Time=0.25 sec
#  ARIMA(1,1,0)(0,1,2)[12]             : AIC=1019.493, Time=0.28 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1020.393, Time=0.09 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=1020.493, Time=0.31 sec
#  ARIMA(1,1,0)(1,1,2)[12]             : AIC=1014.742, Time=0.75 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=1019.239, Time=0.17 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=0.81 sec
#  ARIMA(1,1,0)(2,1,2)[12]             : AIC=inf, Time=1.29 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=1022.393, Time=0.10 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=1022.896, Time=0.19 sec
#  ARIMA(1,1,1)(0,1,2)[12]             : AIC=1021.313, Time=0.49 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=1022.356, Time=0.14 sec
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=1022.299, Time=0.32 sec
#  ARIMA(1,1,1)(1,1,2)[12]             : AIC=1014.990, Time=0.85 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=1021.032, Time=0.34 sec
#  ARIMA(1,1,1)(2,1,1)[12]             : AIC=inf, Time=1.10 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=1024.160, Time=0.41 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=1024.718, Time=0.30 sec
#  ARIMA(1,1,2)(0,1,2)[12]             : AIC=1023.125, Time=0.76 sec
#  ARIMA(1,1,2)(1,1,0)[12]             : AIC=1024.191, Time=0.25 sec
#  ARIMA(1,1,2)(1,1,1)[12]             : AIC=1024.121, Time=0.46 sec
#  ARIMA(1,1,2)(2,1,0)[12]             : AIC=1022.805, Time=0.52 sec
#  ARIMA(1,1,3)(0,1,0)[12]             : AIC=1019.252, Time=0.29 sec
#  ARIMA(1,1,3)(0,1,1)[12]             : AIC=1019.532, Time=0.44 sec
#  ARIMA(1,1,3)(1,1,0)[12]             : AIC=1019.133, Time=0.38 sec
#  ARIMA(1,1,4)(0,1,0)[12]             : AIC=inf, Time=0.40 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=1022.393, Time=0.05 sec
#  ARIMA(2,1,0)(0,1,1)[12]             : AIC=1022.905, Time=0.12 sec
#  ARIMA(2,1,0)(0,1,2)[12]             : AIC=1021.381, Time=0.28 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=1022.373, Time=0.12 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=1022.390, Time=0.32 sec
#  ARIMA(2,1,0)(1,1,2)[12]             : AIC=1015.534, Time=0.97 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=1021.120, Time=0.23 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=1.22 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=1017.847, Time=0.16 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=1018.359, Time=0.33 sec
#  ARIMA(2,1,1)(0,1,2)[12]             : AIC=1017.950, Time=0.59 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=1017.914, Time=0.33 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=1018.248, Time=0.57 sec
#  ARIMA(2,1,1)(2,1,0)[12]             : AIC=1017.658, Time=0.63 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=1019.290, Time=0.17 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=1019.935, Time=0.36 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=1019.546, Time=0.36 sec
#  ARIMA(2,1,3)(0,1,0)[12]             : AIC=1019.796, Time=0.30 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=1023.666, Time=0.06 sec
#  ARIMA(3,1,0)(0,1,1)[12]             : AIC=1024.441, Time=0.16 sec
#  ARIMA(3,1,0)(0,1,2)[12]             : AIC=1023.149, Time=0.39 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=1024.003, Time=0.14 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=1024.141, Time=0.42 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=1022.819, Time=0.25 sec
#  ARIMA(3,1,1)(0,1,0)[12]             : AIC=1019.084, Time=0.19 sec
#  ARIMA(3,1,1)(0,1,1)[12]             : AIC=1019.696, Time=0.44 sec
#  ARIMA(3,1,1)(1,1,0)[12]             : AIC=1019.327, Time=0.33 sec
#  ARIMA(3,1,2)(0,1,0)[12]             : AIC=1021.083, Time=0.34 sec
#  ARIMA(4,1,0)(0,1,0)[12]             : AIC=1021.975, Time=0.08 sec
#  ARIMA(4,1,0)(0,1,1)[12]             : AIC=1022.158, Time=0.17 sec
#  ARIMA(4,1,0)(1,1,0)[12]             : AIC=1021.530, Time=0.16 sec
#  ARIMA(4,1,1)(0,1,0)[12]             : AIC=1023.947, Time=0.16 sec
#  ARIMA(5,1,0)(0,1,0)[12]             : AIC=1023.944, Time=0.09 sec
#
# Best model:  ARIMA(0,1,1)(1,1,2)[12]
# Total fit time: 36.234 seconds

# %%
print(stepwise_model.aic())
# Out:
# 1012.9907964686814

# %%
train = data.loc['1949-01-01':'1959-12-01']
test = data.loc['1960-01-01':]

# %%
train
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1959-08-01          559
# 1959-09-01          463
# 1959-10-01          407
# 1959-11-01          362
# 1959-12-01          405
#
# [132 rows x 1 columns]

# %%
test
# Out:
#             #Passengers
# Month
# 1960-01-01          417
# 1960-02-01          391
# 1960-03-01          419
# 1960-04-01          461
# 1960-05-01          472
# 1960-06-01          535
# 1960-07-01          622
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432

# %%
stepwise_model.fit(train)
# Out:
# ARIMA(order=(0, 1, 1), scoring_args={}, seasonal_order=(1, 1, 2, 12),
#       suppress_warnings=True, with_intercept=False)

# %%
future_forecast = stepwise_model.predict(n_periods=12)

# %%
future_forecast
# Out:
# 1960-01-01    420.318993
# 1960-02-01    398.575696
# 1960-03-01    462.045586
# 1960-04-01    450.821745
# 1960-05-01    474.179139
# 1960-06-01    537.928916
# 1960-07-01    612.312858
# 1960-08-01    623.704985
# 1960-09-01    520.294709
# 1960-10-01    462.476629
# 1960-11-01    413.134675
# 1960-12-01    453.987605
# Freq: MS, dtype: float64

# %%
future_forecast = pd.DataFrame(future_forecast,index = test.index,columns=["#Passengers"])

# %%
pd.concat([test,future_forecast],axis=1).plot()
# Out:
# <Axes: xlabel='Month'>

# %%
pd.concat([data,future_forecast],axis=1).plot(linewidth=3)
# Out:
# <Axes: xlabel='Month'>
